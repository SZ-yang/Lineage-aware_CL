# %% [markdown]
# **1. Change the directory to the google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/scCL/main')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/scCL/main

# %% [markdown]
# **2. Install the packages for scCL**

# %%
# !pip install torch torchvision torchaudio
# !pip install pytorch-lightning
# !pip install anndata
# !pip install lightning-bolts
# !pip install scanpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.2/869.2 kB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 43.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.4.0
#     Uninstalling pytorch-lightning-2.4.0:
#       Successfully uninstalled pytorch-lightning-2.4.0
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 39.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# **3. scCL manual**

# %%
# !python scContrastiveLearning_Main_709_ckpt_epoch.py --help
# Out:
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# ...

# %% [markdown]
# **4. Run scCL**

# %%
# !python scContrastiveLearning_Main_709_ckpt_epoch.py --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/Biddy_train.h5ad" \
                                              --batch_size 50 \
                                              --size_factor 0.04 \
                                              --temperature 0.5 \
                                              --max_epoch 220\
                                              --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/feat_1007_bs40_sf003_biddy_train_test" \
                                              --train_test 1
# Out:
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# ...

# %% [markdown]
# **5. extract the features**

# %%
# !python feature_extraction.py --help
# Out:
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# ...

# %%
# !python feature_extraction.py --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/Biddy_test.h5ad" \
                                              --batch_size 50 \
                                              --size_factor 0.04 \
                                              --temperature 0.5 \
                                              --max_epoch 220\
                                              --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/feat_1007_bs40_sf003_biddy_train_test" \
                                              --train_test 1 \
                                              --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/feat_1007_bs40_sf003_biddy_train_test/saved_models/scContrastiveLearn_last.ckpt"

# "/content/drive/MyDrive/Colab Notebooks/data/Larry_41093_2000_norm_log.h5ad"
# Out:
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# ...

# %%
# !python feature_extraction.py --inputFilePath  "/content/drive/MyDrive/Colab Notebooks/data/Biddy_test.h5ad"\
                                              --batch_size 30 \
                                              --size_factor 0.025 \
                                              --temperature 0.5 \
                                              --max_epoch 220 \
                                              --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/feat_826_bs30_sf0025_biddy_train_test" \
                                              --train_test 1 \
                                              --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/feat_826_bs30_sf0025_biddy_train_test/saved_models/scContrastiveLearn_last.ckpt"
# Out:
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# ...
